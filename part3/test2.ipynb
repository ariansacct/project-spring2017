# %%
# %matplotlib inline

# %%
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap

sf = pd.read_csv("sample_flat.csv")
sf["names"] = sf["names"].astype('str')

# %%
fig, axes = plt.subplots(nrows=4, ncols=2, figsize=(20, 20))
sf.boxplot(column="quant1", ax=axes[0, 0])
#plt.show()
sf.boxplot(column="quant2", ax=axes[0, 1])
#plt.show()
sf.boxplot(column="quant3", ax=axes[1, 0])
plt.show()

# %%
plt.figure()
plt.subplot(2, 2, 1)
plt.plot([1, 2, 3])

plt.subplot(2, 2, 3)
ax = plt.gca()
#sf.boxplot('val', 'day', ax=ax)
sf.boxplot(column="quant1", ax=ax)

ax = plt.gca()
plt.subplot(2, 2, 4)
sf.boxplot(column="quant2", ax=ax)
